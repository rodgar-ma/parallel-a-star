# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
plt.rcParams.update({"font.family": "serif",
                     "font.size": 28,
                     "axes.grid": False})

# %% [markdown]
# # Random Maps

# %%
x = np.linspace(1, 8, 8)

seq_random_10 = np.array([158.118324])
seq_random_15 = np.array([225.653858])
seq_random_20 = np.array([284.636442])
seq_random_25 = np.array([341.557573])
seq_random_30 = np.array([332.936916])
seq_random_35 = np.array([426.869097])
seq_random_40 = np.array([205.113508])

spa_random_10 = np.array([175.058103, 250.540092, 279.995708, 303.328761, 318.956196, 335.620726, 362.388061, 356.857639])
spa_random_15 = np.array([244.881407, 348.807989, 390.616123, 426.851486, 443.454290, 466.545639, 502.915970, 487.415404])
spa_random_20 = np.array([304.049725, 423.844806, 468.493375, 510.920828, 534.177611, 563.554605, 602.117385, 597.270232])
spa_random_25 = np.array([363.589288, 510.121875, 572.587129, 617.398259, 644.074456, 673.569015, 748.503136, 718.569563])
spa_random_30 = np.array([358.331403, 512.316997, 572.446193, 619.193467, 630.110549, 673.488742, 744.835287, 706.327411])
spa_random_35 = np.array([454.341652, 637.425815, 702.441279, 771.489533, 776.552789, 834.406279, 895.042705, 877.573678])
spa_random_40 = np.array([211.624770, 293.279168, 336.128862, 355.220405, 377.690579, 395.926212, 430.420718, 431.293343])

hda_random_10 = np.array([171.732651, 179.587124, 167.014167, 145.389306, 133.446999, 143.629177, 107.985342, 119.397970])
hda_random_15 = np.array([243.635437, 233.958685, 196.808613, 192.502034, 172.231217, 178.158055, 129.147283, 147.052317])
hda_random_20 = np.array([288.596038, 274.174109, 238.723460, 233.557096, 198.418612, 197.031636, 161.918825, 181.483964])
hda_random_25 = np.array([374.887336, 331.361543, 273.539281, 261.786801, 238.415987, 239.088056, 206.480110, 213.886044])
hda_random_30 = np.array([372.540347, 332.936490, 271.219412, 302.809560, 225.736118, 228.640698, 172.044943, 233.027863])
hda_random_35 = np.array([450.791066, 410.063716, 330.559864, 322.185174, 258.796892, 277.020759, 207.223479, 256.101149])
hda_random_40 = np.array([240.978404, 195.574707, 169.627457, 173.650448, 143.895019, 148.918793, 113.388422, 151.915722])

# %%
# Crear la figura y el eje
plt.figure(figsize=(10, 6))

# Dibujar cada array
plt.hlines(seq_random_10, xmin=1, xmax=8, label='A*', color='black', linewidth=3)
plt.plot(x, spa_random_10, label='SPA*', color='black', linestyle='dotted')
plt.plot(x, hda_random_10, label='HDA*', color='black', linestyle='dashed')

# Configuraciones opcionales
plt.xlabel('Número de hilos')
plt.ylabel('Tiempo (ms)')
plt.title('Mapa aleatorio (10% obstáculos)')
plt.legend()
plt.grid(True)

plt.savefig('../../latex/plots/random/random_10.svg', format='svg')

# Mostrar la gráfica
plt.show()

# %%
# Crear la figura y el eje
plt.figure(figsize=(10, 6))

# Dibujar cada array
plt.hlines(seq_random_15, xmin=1, xmax=8, label='A*', color='black', linewidth=3)
plt.plot(x, spa_random_15, label='SPA*', color='black', linestyle='dotted')
plt.plot(x, hda_random_15, label='HDA*', color='black', linestyle='dashed')

# Configuraciones opcionales
plt.xlabel('Número de hilos')
plt.ylabel('Tiempo (ms)')
plt.title('Mapa aleatorio (15% obstáculos)')
plt.legend()
plt.grid(True)

plt.savefig('../../latex/plots/random/random_15.svg', format='svg')

# Mostrar la gráfica
plt.show()

# %%
# Crear la figura y el eje
plt.figure(figsize=(10, 6))

# Dibujar cada array
plt.hlines(seq_random_20, xmin=1, xmax=8, label='A*', color='black', linewidth=3)
plt.plot(x, spa_random_20, label='SPA*', color='black', linestyle='dotted')
plt.plot(x, hda_random_20, label='HDA*', color='black', linestyle='dashed')

# Configuraciones opcionales
plt.xlabel('Número de hilos')
plt.ylabel('Tiempo (ms)')
plt.title('Mapa aleatorio (20% obstáculos)')
plt.legend()
plt.grid(True)

plt.savefig('../../latex/plots/random/random_20.svg', format='svg')

# Mostrar la gráfica
plt.show()

# %%
# Crear la figura y el eje
plt.figure(figsize=(10, 6))

# Dibujar cada array
plt.hlines(seq_random_25, xmin=1, xmax=8, label='A*', color='black', linewidth=3)
plt.plot(x, spa_random_25, label='SPA*', color='black', linestyle='dotted')
plt.plot(x, hda_random_25, label='HDA*', color='black', linestyle='dashed')

# Configuraciones opcionales
plt.xlabel('Número de hilos')
plt.ylabel('Tiempo (ms)')
plt.title('Mapa aleatorio (25% obstáculos)')
plt.legend()
plt.grid(True)

plt.savefig('../../latex/plots/random/random_25.svg', format='svg')

# Mostrar la gráfica
plt.show()

# %%
# Crear la figura y el eje
plt.figure(figsize=(10, 6))

# Dibujar cada array
plt.hlines(seq_random_30, xmin=1, xmax=8, label='A*', color='black', linewidth=3)
plt.plot(x, spa_random_30, label='SPA*', color='black', linestyle='dotted')
plt.plot(x, hda_random_30, label='HDA*', color='black', linestyle='dashed')

# Configuraciones opcionales
plt.xlabel('Número de hilos')
plt.ylabel('Tiempo (ms)')
plt.title('Mapa aleatorio (30% obstáculos)')
plt.legend()
plt.grid(True)

plt.savefig('../../latex/plots/random/random_30.svg', format='svg')

# Mostrar la gráfica
plt.show()

# %%
# Crear la figura y el eje
plt.figure(figsize=(10, 6))

# Dibujar cada array
plt.hlines(seq_random_35, xmin=1, xmax=8, label='A*', color='black', linewidth=3)
plt.plot(x, spa_random_35, label='SPA*', color='black', linestyle='dotted')
plt.plot(x, hda_random_35, label='HDA*', color='black', linestyle='dashed')

# Configuraciones opcionales
plt.xlabel('Número de hilos')
plt.ylabel('Tiempo (ms)')
plt.title('Mapa aleatorio (35% obstáculos)')
plt.legend()
plt.grid(True)

plt.savefig('../../latex/plots/random/random_35.svg', format='svg')

# Mostrar la gráfica
plt.show()

# %%
# Crear la figura y el eje
plt.figure(figsize=(10, 6))

# Dibujar cada array
plt.hlines(seq_random_40, xmin=1, xmax=8, label='A*', color='black', linewidth=3)
plt.plot(x, spa_random_40, label='SPA*', color='black', linestyle='dotted')
plt.plot(x, hda_random_40, label='HDA*', color='black', linestyle='dashed')

# Configuraciones opcionales
plt.xlabel('Número de hilos')
plt.ylabel('Tiempo (ms)')
plt.title('Mapa aleatorio (40% obstáculos)')
plt.legend()
plt.grid(True)

plt.savefig('../../latex/plots/random/random_40.svg', format='svg')

# Mostrar la gráfica
plt.show()

# %% [markdown]
# # Maze Maps

# %%
x = np.linspace(1, 8, 8)

seq_maze_1 = np.array([281.498184])
seq_maze_2 = np.array([477.044288])
seq_maze_4 = np.array([615.472549])
seq_maze_8 = np.array([710.428015])
seq_maze_16 = np.array([751.437983])
seq_maze_32 = np.array([787.724579])

spa_maze_1 = np.array([343.291893, 459.610996, 572.520284, 626.164126, 705.919348, 711.747741, 704.427463, 765.980896])
spa_maze_2 = np.array([543.027301, 729.795984, 861.900090, 922.252808, 1032.078241, 1077.520760, 1025.825831, 1189.417714])
spa_maze_4 = np.array([699.180068, 920.528783, 1088.873701, 1171.645485, 1287.501497, 1374.806553, 1322.665653, 1467.780519])
spa_maze_8 = np.array([814.674400, 1095.726686, 1288.085418, 1469.401606, 1536.428527, 1611.813419, 1576.970995, 1679.773252])
spa_maze_16 = np.array([878.981659, 1153.770973, 1347.698231, 1421.002427, 1638.262821, 1725.059960, 1663.960923, 1778.796064])
spa_maze_32 = np.array([937.164553, 1238.744793, 1442.206431, 1652.043401, 1767.428759, 1880.092091, 1794.319845, 1874.173564])

hda_maze_1 = np.array([305.092231, 401.279302, 296.631174, 318.605317, 249.657818, 413.649263, 283.770214, 454.317362])
hda_maze_2 = np.array([500.725320, 579.112417, 486.279323, 421.712379, 417.922699, 454.272561, 372.932651, 406.744932])
hda_maze_4 = np.array([648.655194, 744.141360, 675.456334, 543.026676, 572.349199, 590.037576, 524.698802, 478.338268])
hda_maze_8 = np.array([751.478352, 944.114435, 770.659745, 673.093967, 732.299009, 756.166910, 614.088257, 617.122735])
hda_maze_16 = np.array([810.490177, 1002.811642, 852.185837, 725.686252, 819.553734,  798.065691, 706.851181, 631.445915])
hda_maze_32 = np.array([847.042290, 1079.076300, 950.726720, 783.437675, 887.483355, 863.965965, 805.298741, 639.422270])

# %%
# Crear la figura y el eje
plt.figure(figsize=(10, 6))

# Dibujar cada array
plt.hlines(seq_maze_1, xmin=1, xmax=8, label='A*', color='black', linewidth=3)
plt.plot(x, spa_maze_1, label='SPA*', color='black', linestyle='dotted')
plt.plot(x, hda_maze_1, label='HDA*', color='black', linestyle='dashed')

# Configuraciones opcionales
plt.xlabel('Número de hilos')
plt.ylabel('Tiempo (ms)')
plt.title('Laberinto (512 x 512 x 1)')
plt.legend()
plt.grid(True)

plt.savefig('../../latex/plots/maze/maze_1.svg', format='svg')

# Mostrar la gráfica
plt.show()

# %%
# Crear la figura y el eje
plt.figure(figsize=(10, 6))

# Dibujar cada array
plt.hlines(seq_maze_2, xmin=1, xmax=8, label='A*', color='black', linewidth=3)
plt.plot(x, spa_maze_2, label='SPA*', color='black', linestyle='dotted')
plt.plot(x, hda_maze_2, label='HDA*', color='black', linestyle='dashed')

# Configuraciones opcionales
plt.xlabel('Número de hilos')
plt.ylabel('Tiempo (ms)')
plt.title('Laberinto (512 x 512 x 2)')
plt.legend()
plt.grid(True)

plt.savefig('../../latex/plots/maze/maze_2.svg', format='svg')

# Mostrar la gráfica
plt.show()

# %%
# Crear la figura y el eje
plt.figure(figsize=(10, 6))

# Dibujar cada array
plt.hlines(seq_maze_4, xmin=1, xmax=8, label='A*', color='black', linewidth=3)
plt.plot(x, spa_maze_4, label='SPA*', color='black', linestyle='dotted')
plt.plot(x, hda_maze_4, label='HDA*', color='black', linestyle='dashed')

# Configuraciones opcionales
plt.xlabel('Número de hilos')
plt.ylabel('Tiempo (ms)')
plt.title('Laberinto (512 x 512 x 4)')
plt.legend()
plt.grid(True)

plt.savefig('../../latex/plots/maze/maze_4.svg', format='svg')

# Mostrar la gráfica
plt.show()

# %%
# Crear la figura y el eje
plt.figure(figsize=(10, 6))

# Dibujar cada array
plt.hlines(seq_maze_8, xmin=1, xmax=8, label='A*', color='black', linewidth=3)
plt.plot(x, spa_maze_8, label='SPA*', color='black', linestyle='dotted')
plt.plot(x, hda_maze_8, label='HDA*', color='black', linestyle='dashed')

# Configuraciones opcionales
plt.xlabel('Número de hilos')
plt.ylabel('Tiempo (ms)')
plt.title('Laberinto (512 x 512 x 8)')
plt.legend()
plt.grid(True)

plt.savefig('../../latex/plots/maze/maze_8.svg', format='svg')

# Mostrar la gráfica
plt.show()

# %%
# Crear la figura y el eje
plt.figure(figsize=(10, 6))

# Dibujar cada array
plt.hlines(seq_maze_16, xmin=1, xmax=8, label='A*', color='black', linewidth=3)
plt.plot(x, spa_maze_16, label='SPA*', color='black', linestyle='dotted')
plt.plot(x, hda_maze_16, label='HDA*', color='black', linestyle='dashed')

# Configuraciones opcionales
plt.xlabel('Número de hilos')
plt.ylabel('Tiempo (ms)')
plt.title('Laberinto (512 x 512 x 16)')
plt.legend()
plt.grid(True)

plt.savefig('../../latex/plots/maze/maze_16.svg', format='svg')

# Mostrar la gráfica
plt.show()

# %%
# Crear la figura y el eje
plt.figure(figsize=(10, 6))

# Dibujar cada array
plt.hlines(seq_maze_32, xmin=1, xmax=8, label='A*', color='black', linewidth=3)
plt.plot(x, spa_maze_32, label='SPA*', color='black', linestyle='dotted')
plt.plot(x, hda_maze_32, label='HDA*', color='black', linestyle='dashed')

# Configuraciones opcionales
plt.xlabel('Número de hilos')
plt.ylabel('Tiempo (ms)')
plt.title('Laberinto (512 x 512 x 32)')
plt.legend()
plt.grid(True)

plt.savefig('../../latex/plots/maze/maze_32.svg', format='svg')

# Mostrar la gráfica
plt.show()

# %% [markdown]
# # Starcraft

# %%
x = np.linspace(1, 8, 8)

seq_starcraft = np.array([1580.465492])

spa_starcraft = np.array([1836.672710, 2488.98745, 2994.199334, 3224.656334, 3227.260813, 3500.018719, 3686.413691, 3609.257718])

hda_starcraft = np.array([1763.915820, 1844.900404, 1617.122444, 1377.481381, 1317.614125, 1467.282870, 1433.986733, 1134.022454])

# %%
# Crear la figura y el eje
plt.figure(figsize=(10, 6))

# Dibujar cada array
plt.hlines(seq_starcraft, xmin=1, xmax=8, label='A*', color='black', linewidth=3)
plt.plot(x, spa_starcraft, label='SPA*', color='black', linestyle='dotted')
plt.plot(x, hda_starcraft, label='HDA*', color='black', linestyle='dashed')

# Configuraciones opcionales
plt.xlabel('Número de hilos')
plt.ylabel('Tiempo (ms)')
plt.title('Starcraft (1024 x 1024)')
plt.legend()
plt.grid(True)

plt.savefig('../../latex/plots/games/starcraft.svg', format='svg')

# Mostrar la gráfica
plt.show()

# %% [markdown]
# # Dragon Age: Origins

# %%
x = np.linspace(1, 8, 8)

seq_lak505d = np.array([37.993900])

spa_lak505d = np.array([45.992400, 53.758833, 65.778899, 69.790050, 71.590017, 79.239967, 75.552676, 86.748800])

hda_lak505d = np.array([43.063076, 54.832433, 48.970399, 50.403200, 40.229400, 44.938600, 45.379676, 43.671559])

# %%
# Crear la figura y el eje
plt.figure(figsize=(10, 6))

# Dibujar cada array
plt.hlines(seq_lak505d, xmin=1, xmax=8, label='A*', color='black', linewidth=3)
plt.plot(x, spa_lak505d, label='SPA*', color='black', linestyle='dotted')
plt.plot(x, hda_lak505d, label='HDA*', color='black', linestyle='dashed')

# Configuraciones opcionales
plt.xlabel('Número de hilos')
plt.ylabel('Tiempo (ms)')
plt.title('Dragon Age (194 x 195)')
plt.legend()
plt.grid(True)

plt.savefig('../../latex/plots/games/dao.svg', format='svg')

# Mostrar la gráfica
plt.show()

# %% [markdown]
# # Synthetic Maps

# %%
x = np.linspace(1, 8, 8)

seq_maze1000 = np.array([250.307749])
seq_test = np.array([3.713750])
seq_noobstacle = np.array([57.660994])

spa_maze1000 = np.array([313.450743, 418.769230, 489.064010, 544.263943, 553.112923, 568.172070, 632.440437, 628.789705])
spa_test = np.array([5.249252, 9.169642, 17.043658, 19.621341, 23.880076, 26.832385, 31.768953, 34.927518])
spa_noobstacle = np.array([60.697596, 143.894342, 176.829509, 220.205463, 268.679416, 310.951033, 354.223417, 378.415800])

hda_maze1000 = np.array([271.436061, 242.571297, 247.060457, 162.024973, 192.111998, 180.723052, 191.385530, 212.542711])
hda_test = np.array([4.050493, 9.829475, 17.373794, 25.609892, 35.874766, 52.729198, 59.991951, 81.605242])
hda_noobstacle = np.array([214.861366, 298.286406, 240.304023, 331.160239, 355.538546, 421.116446, 444.978294, 520.624224])

# %%
# Crear la figura y el eje
plt.figure(figsize=(10, 6))

# Dibujar cada array
plt.hlines(seq_maze1000, xmin=1, xmax=8, label='A*', color='black', linewidth=3)
plt.plot(x, spa_maze1000, label='SPA*', color='black', linestyle='dotted')
plt.plot(x, hda_maze1000, label='HDA*', color='black', linestyle='dashed')

# Configuraciones opcionales
plt.xlabel('Número de hilos')
plt.ylabel('Tiempo (ms)')
plt.title('Laberinto (1000 x 1000 x 1)')
plt.legend()
plt.grid(True)

plt.savefig('../../latex/plots/synthetic/maze1000.svg', format='svg')

# Mostrar la gráfica
plt.show()

# %%
# Crear la figura y el eje
plt.figure(figsize=(10, 6))

# Dibujar cada array
plt.hlines(seq_test, xmin=1, xmax=8, label='A*', color='black', linewidth=3)
plt.plot(x, spa_test, label='SPA*', color='black', linestyle='dotted')
plt.plot(x, hda_test, label='HDA*', color='black', linestyle='dashed')

# Configuraciones opcionales
plt.xlabel('Número de hilos')
plt.ylabel('Tiempo (ms)')
plt.title('Mapa de dos caminos')
plt.legend()
plt.grid(True)

plt.savefig('../../latex/plots/synthetic/test.svg', format='svg')

# Mostrar la gráfica
plt.show()

# %%
# Crear la figura y el eje
plt.figure(figsize=(10, 6))

# Dibujar cada array
plt.hlines(seq_noobstacle, xmin=1, xmax=8, label='A*', color='black', linewidth=3)
plt.plot(x, spa_noobstacle, label='SPA*', color='black', linestyle='dotted')
plt.plot(x, hda_noobstacle, label='HDA*', color='black', linestyle='dashed')

# Configuraciones opcionales
plt.xlabel('Número de hilos')
plt.ylabel('Tiempo (ms)')
plt.title('Mapa sin obstáculos')
plt.legend()
plt.grid(True)

plt.savefig('../../latex/plots/synthetic/noobstacle.svg', format='svg')

# Mostrar la gráfica
plt.show()

# %% [markdown]
# # Threshold

# %%
x = np.array([1, 10, 100, 1000, 10000])

hda_threshold_4 = np.array([209.5014, 175.77794, 172.438, 158.90967, 171.55172])
hda_threshold_8 = np.array([303.679865, 259.15872333, 282.46706233, 201.77059625, 257.492355])

# %%
np.mean([241.790777, 253.541038, 257.492355])
# Out:
# np.float64(250.94138999999998)

# %%
# Crear la figura y el eje
plt.figure(figsize=(10, 6))

# Dibujar cada array
plt.plot(x, hda_threshold_4, color='black')

# Configuraciones opcionales
plt.xlabel('Threshold')
plt.ylabel('Tiempo (ms)')
plt.title('HDA* con 4 hilos')
plt.legend()
plt.grid(True)
plt.xscale('log')

plt.savefig('../../latex/plots/threshold_4.svg', format='svg')

# Mostrar la gráfica
plt.show()
# Out:
# /var/folders/48/96ptk_j51w5dzt53ys2z52ww0000gn/T/ipykernel_15863/4178969685.py:11: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %%
# Crear la figura y el eje
plt.figure(figsize=(10, 6))

# Dibujar cada array
plt.plot(x, hda_threshold_8, color='black')

# Configuraciones opcionales
plt.xlabel('Threshold')
plt.ylabel('Tiempo (ms)')
plt.title('HDA* con 8 hilos')
plt.legend()
plt.grid(True)
plt.xscale('log')

plt.savefig('../../latex/plots/threshold_8.svg', format='svg')

# Mostrar la gráfica
plt.show()
# Out:
# /var/folders/48/96ptk_j51w5dzt53ys2z52ww0000gn/T/ipykernel_15863/2893862092.py:11: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %% [markdown]
# # Slow Expansion

# %%
x = np.linspace(1, 8, 8)

seq_slowexp = np.array([509062.271776])
spa_slowexp = np.array([509101.044538, 296057.873882, 246043.391918, 216040.960603, 202040.727503, 199043.488276, 196037.375380, 170026.292500])
hda_slowexp = np.array([499095.155859, 320061.512156, 264048.350595, 281051.234516, 238039.451520, 234045.486276, 255565.667366, 251490.972296])

# %%
# Crear la figura y el eje
plt.figure(figsize=(10, 6))

# Dibujar cada array
plt.hlines(seq_slowexp, xmin=1, xmax=8, label='A*', color='black', linewidth=3)
plt.plot(x, spa_slowexp, label='SPA*', color='black', linestyle='dotted')
plt.plot(x, hda_slowexp, label='HDA*', color='black', linestyle='dashed')

# Configuraciones opcionales
plt.xlabel('Número de hilos')
plt.ylabel('Tiempo (ms)')
plt.title('Operación de expansión costosa')
plt.legend()
plt.grid(True)

plt.savefig('../../latex/plots/slowexp.svg', format='svg')

# Mostrar la gráfica
plt.show()
